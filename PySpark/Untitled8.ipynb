# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/labuser/Downloads/IMDB-Movie-Data.csv')

# %%
x = plt.scatter(df['Rating'], df['Revenue (Millions)'], color=['red'])

# %%
df.shape
# Out:
# (1000, 12)

# %%
colors = ['red', 'yellow', 'green', 'blue']
df_list = [df1, df2, df3, df4]

# %%
for i in range(0, 4):
    plt.scatter(df_list[i]['Rating'], df_list[i]['Revenue (Millions)'], color=colors[i])

# %%
df1 = df.iloc[:200,]

# %%
df2 = df.iloc[200:400,]

# %%
df3 = df.iloc[400:600, ]

# %%
df4 = df.iloc[600:800,]

# %%
colormap = np.array(['r', 'g', 'b'])
 
# depict illustration
plt.scatter(df['Revenue (Millions)'], df['Rating'], s=100, c=colormap[ll])

# %%
import random

# %%
categories = np.array([0, 1, 2, 0, 1, 2, 0, 1, 2])

# %%
ll = []
for i in range(0, 1000):
    ll.append(random.randint(0,2))

# %%
len(ll)
# Out:
# 1000
